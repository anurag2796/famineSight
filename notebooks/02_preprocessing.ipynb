# %% [markdown]
# # FamineSight: Data Preprocessing
#
# This notebook demonstrates the data preprocessing pipeline including imputation, outlier clipping, and feature scaling.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import os

# Add project root to path
sys.path.insert(0, os.path.abspath('..'))

# %% [markdown]
# ## Setup & Configuration

# %%
from src.config import DATA_PROC, DATA_RAW
print(f'Data Directory: {DATA_PROC}')

# %% [markdown]
# ## Load Data

# %%
# Example data loading
try:
    df = pd.read_parquet(DATA_PROC / 'master_panel.parquet')
    print(df.head())
except Exception as e:
    print(f'Could not load data: {e}')
